# %%
import gensim
one_model_path = os.path.join("/media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw",str(20131228)+"/ModelResult/model-size%s"%str(100))
model = gensim.models.Word2Vec.load_word2vec_format(one_model_path+"/model-all-word2vec", fvocab=one_model_path+"/model-all-vocabulary", binary=False)

# %%
model.most_similar("short.weixin.qq.com",topn=10)
# Out:
# [('dns.weixin.qq.com', 0.8793339729309082),
#  ('mmsns.qpic.cn', 0.8386834263801575),
#  ('wx.qlogo.cn', 0.7772337198257446),
#  ('mmbiz.qpic.cn', 0.7722837328910828),
#  ('mp.weixin.qq.com', 0.7045636773109436),
#  ('szshort.weixin.qq.com', 0.6930785179138184),
#  ('view.inews.qq.com', 0.6905420422554016),
#  ('res.wx.qq.com', 0.6884949207305908),
#  ('112.25.58.198', 0.6794305443763733),
#  ('pnewsapp.tc.qq.com', 0.6770601868629456)]

# %%
model.most_similar("xiaomi.m.tmall.com", topn=10)
# Out:
# [('sdeerconcept.m.tmall.com', 0.9332772493362427),
#  ('suxingdeleyuan.m.tmall.com', 0.9253667593002319),
#  ('gxg.m.tmall.com', 0.9217509031295776),
#  ('sdeer.m.tmall.com', 0.9163999557495117),
#  ('kaifandiml.m.tmall.com', 0.9151037335395813),
#  ('etam.m.tmall.com', 0.9130758047103882),
#  ('fanersen.m.tmall.com', 0.9130244255065918),
#  ('me-city.m.tmall.com', 0.9129284620285034),
#  ('thermos.m.tmall.com', 0.9124237895011902),
#  ('lzfur.m.tmall.com', 0.9114028811454773)]

# %%
model.most_similar("app100666690.qzone.qzoneapp.com", topn=10)
# Out:
# [('shopchuchujie.u.qiniudn.com', 0.7543945908546448),
#  ('app100666690.qzoneapp.com', 0.712559700012207),
#  ('1251001080.cdn.myqcloud.com', 0.674208402633667),
#  ('app100620636.qzone.qzoneapp.com', 0.6708102226257324),
#  ('shop.chuchujie.com', 0.6532361507415771),
#  ('app31328.qzone.qzoneapp.com', 0.627905547618866),
#  ('app100636148.qzone.qzoneapp.com', 0.6226035356521606),
#  ('mapp.chuchujie.com', 0.6095552444458008),
#  ('mapptg.culiu.org', 0.6064537167549133),
#  ('app100666690.imgcache.qzoneapp.com', 0.599612832069397)]

# %%
model.most_similar("meimeizhu.wap.blog.163.com", topn=10)
# Out:
# [('wd58km64.wap.blog.163.com', 0.982840895652771),
#  ('ielulu.wap.blog.163.com', 0.8994159698486328),
#  ('axh0310.wap.blog.163.com', 0.8811402320861816),
#  ('illlady.wap.blog.163.com', 0.8593229055404663),
#  ('kstxp.wap.blog.163.com', 0.8432925939559937),
#  ('sea-fun.wap.blog.163.com', 0.84299635887146),
#  ('lfcncidc.blog.163.com', 0.8360276222229004),
#  ('cgr606.wap.blog.163.com', 0.8355950117111206),
#  ('qjwjywx.wap.blog.163.com', 0.8289450407028198),
#  ('xiaorui58126.wap.blog.163.com', 0.8237395286560059)]

# %%
[i for i in model.index2word if "wap.blog.163.com" in i]
# Out:
# ['wap.blog.163.com',
#  'shijuzhikublog.wap.blog.163.com',
#  'meimeizhu.wap.blog.163.com',
#  'baiyalingling.wap.blog.163.com',
#  'lag1967.wap.blog.163.com',
#  'greatbook.wap.blog.163.com',
#  'liguangyun866.wap.blog.163.com',
#  'jrtsung.wap.blog.163.com',
#  'axh0310.wap.blog.163.com',
#  'qikaimao20020815.wap.blog.163.com',
#  'zhengzhi0353.wap.blog.163.com',
#  'yatou-yh.wap.blog.163.com',
#  'xadszags.wap.blog.163.com',
#  'dtdg777.wap.blog.163.com',
#  'kstxp.wap.blog.163.com',
#  'fantasyruah.wap.blog.163.com',
#  'licaiguihua22.wap.blog.163.com',
#  'wd58km64.wap.blog.163.com',
#  'ghl211.wap.blog.163.com',
#  'd1600633398.wap.blog.163.com',
#  'tiantian0928.wap.blog.163.com',
#  'liang0513.wap.blog.163.com',
#  'lk1727856510.wap.blog.163.com',
#  'qjwjywx.wap.blog.163.com',
#  'xin1016.wap.blog.163.com',
#  'ielulu.wap.blog.163.com',
#  'sunny-9196271.wap.blog.163.com',
#  'hhhhml.wap.blog.163.com',
#  'gay7418529630.wap.blog.163.com',
#  'jiepai7.wap.blog.163.com',
# ...

# %%
import gensim
for i in [20131228,20131229,20131230,20131231,20140101,20140102,20140103]:
    one_model_path = os.path.join("/media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw",str(i)+"/ModelResult/model-size%s"%str(100))
    model = gensim.models.Word2Vec.load_word2vec_format(one_model_path+"/model-all-word2vec", fvocab=one_model_path+"/model-all-vocabulary", binary=False)
    print("-----_>>>>",i)
    print(model.most_similar("m.baidu.com", topn=10))
# Out:
# -----_>>>> 20131228
# [('wap.baidu.com', 0.718451201915741), ('timg01.baidu-2img.cn', 0.7175188064575195), ('111.13.12.43', 0.7074019908905029), ('4881.zkl90.com', 0.6876076459884644), ('fclick.baidu.com', 0.687528669834137), ('aladdin.wapmap.baidu.com', 0.6829685568809509), ('ms.bdimg.com', 0.6780153512954712), ('www.qingxinwang.com', 0.6759989261627197), ('wap.wyn88.com', 0.6757994890213013), ('mt1.baidu.com', 0.6750012636184692)]
# -----_>>>> 20131229
# [('111.13.12.43', 0.6937652826309204), ('timg01.baidu-2img.cn', 0.684453547000885), ('mt1.baidu.com', 0.680195689201355), ('www.99rt.cc', 0.6745342016220093), ('wap.baidu.com', 0.6709209680557251), ('446aa.com', 0.6687145829200745), ('3g.shouzu.com', 0.6668835878372192), ('www.78sege.com', 0.6637740135192871), ('ms.bdimg.com', 0.6612892150878906), ('list.92le.com', 0.6602940559387207)]
# -----_>>>> 20131230
# ...

# %%
model.most_similar("api.diditaxi.com.cn",topn=10)
# Out:
# [('diditaxi.com.cn', 0.842455267906189),
#  ('open.nav.map.qq.com', 0.8040945529937744),
#  ('f1.kuaidadi.com', 0.7942723035812378),
#  ('c2.kuaidadi.com', 0.7921994924545288),
#  ('lbssp.map.qq.com', 0.7103291749954224),
#  ('gather.lotuseed.com', 0.70270836353302),
#  ('vector.map.soso.com', 0.6789028644561768),
#  ('api.hcicloud.com', 0.6663504242897034),
#  ('online.lotuseed.com', 0.6279028654098511),
#  ('tapi.yuebaowang.com', 0.6083105802536011)]

# %%
model.most_similar("api.kuaidi.360.cn",topn=20)
# Out:
# [('update.mobilem.360.cn', 0.819295346736908),
#  ('openbox.mobilem.360.cn', 0.8088212013244629),
#  ('p19.qhimg.com', 0.8005564212799072),
#  ('openboxcdn.mobilem.360.cn', 0.7630580067634583),
#  ('m.leidian.com', 0.7536547183990479),
#  ('id.mobilem.360.cn', 0.736122727394104),
#  ('intf1.zsall.mobilem.360.cn', 0.7343376874923706),
#  ('profile.openapi.360.cn', 0.7298296689987183),
#  ('upload2.kuaidi.360.cn', 0.7275755405426025),
#  ('api.shuaji.360.cn', 0.722297728061676),
#  ('mse.hao.360.cn', 0.7198258638381958),
#  ('res.qhsetup.com', 0.716346025466919),
#  ('p17.qhimg.com', 0.7135263681411743),
#  ('m.shouji.360tpcdn.com', 0.7124533653259277),
#  ('cloudscan.shouji.360.cn', 0.7096544504165649),
#  ('msg.shouji.360.cn', 0.7039927244186401),
#  ('p16.qhimg.com', 0.7033820748329163),
#  ('cx.shouji.360.cn', 0.7009446024894714),
#  ('p15.qhimg.com', 0.7003852128982544),
#  ('fake.api.mobilem.360.cn', 0.6946940422058105)]

# %%
model.most_similar("www.12306.cn", topn=10)
# Out:
# [('dynamic.12306.cn', 0.7916898727416992),
#  ('trains.ctrip.com', 0.7385430335998535),
#  ('ws.qunar.com', 0.720790445804596),
#  ('suanya.cn', 0.7197213172912598),
#  ('tongji.kuxun.cn', 0.7101433277130127),
#  ('kyfw.12306.cn', 0.7059718370437622),
#  ('unionpaysecure.com', 0.6931651830673218),
#  ('trainfinder.ikamobile.cn', 0.6929464340209961),
#  ('m.kuxun.cn', 0.686222493648529),
#  ('qunarzz.com', 0.6856034994125366)]

# %%
model.most_similar("api.jiakaobaodian.com",topn=10)
# Out:
# [('ad.kakamobi.com', 0.9844129681587219),
#  ('domob.kakamobi.com', 0.9834868311882019),
#  ('www.jiakaobaodian.com', 0.9595677852630615),
#  ('ke3.jiakaobaodian.com', 0.9459105730056763),
#  ('mucang.oss.aliyuncs.com', 0.9447270631790161),
#  ('mucang.oss-cn-hangzhou.aliyuncs.com', 0.944338321685791),
#  ('note.kakamobi.com', 0.943822979927063),
#  ('static.kakamobi.com', 0.9430306553840637),
#  ('form.kakamobi.com', 0.9423243999481201),
#  ('ke1.jiakaobaodian.com', 0.939528226852417)]

# %%
model.most_similar("ad.kakamobi.com",topn=10)
# Out:
# [('api.jiakaobaodian.com', 0.9844129681587219),
#  ('domob.kakamobi.com', 0.9815046787261963),
#  ('www.jiakaobaodian.com', 0.957478940486908),
#  ('ke3.jiakaobaodian.com', 0.9437640905380249),
#  ('note.kakamobi.com', 0.9400326609611511),
#  ('static.kakamobi.com', 0.9381704330444336),
#  ('ke1.jiakaobaodian.com', 0.9375894665718079),
#  ('form.kakamobi.com', 0.9357284307479858),
#  ('shijia.kakamobi.com', 0.9356472492218018),
#  ('mucang.oss-cn-hangzhou.aliyuncs.com', 0.933054506778717)]

# %%
model.most_similar("shop71474050.m.taobao.com",topn=10)
# Out:
# [('shop106043365.m.taobao.com', 0.9907625317573547),
#  ('shop72844347.m.taobao.com', 0.9894018173217773),
#  ('shop72697823.m.taobao.com', 0.9892649054527283),
#  ('shop61054415.m.taobao.com', 0.9887192249298096),
#  ('shop70734414.m.taobao.com', 0.9753414988517761),
#  ('shop36657108.m.taobao.com', 0.9293947219848633),
#  ('shop67659695.m.taobao.com', 0.9168536067008972),
#  ('shop60943368.m.taobao.com', 0.9091731309890747),
#  ('yobeyi.m.tmall.com', 0.8969091176986694),
#  ('shop57644582.m.taobao.com', 0.8926298022270203)]

# %%
for i in model.most_similar("adclick.g.doubleclick.net",topn=20):
    if "google" not in i[0]:
        print(i)
# Out:
# ('app.yiche.com', 0.8326520919799805)
# ('ut.gtags.net', 0.8014647364616394)
# ('s.zampdsp.com', 0.7916465997695923)
# ('cdn.zampdsp.com', 0.7570028305053711)
# ('media.admob.com', 0.7558121681213379)
# ('www1.runnergameshk.com', 0.7040297985076904)
# ('ad.61he.com', 0.6977735757827759)
# ('www.runnergameshk.com', 0.6948592066764832)
# ('csi.gstatic.com', 0.6915092468261719)
# ('dv0ilapexlwkm.cloudfront.net', 0.6894874572753906)
# ('www.qsolar.net', 0.6864020824432373)
# ('babypush-baodian.stor.sinaapp.com', 0.6853799819946289)
# ('oooselfad0.appspot.com', 0.6842584013938904)
# ('yuntuadmin.azurewebsites.net', 0.6838383078575134)
# ('m.qsolar.net', 0.6817485094070435)
# ('api.tapfortap.com', 0.6795551776885986)
# ('videoad.android.maxpedia.org', 0.6789945960044861)
# ('mds.51.com', 0.6771934628486633)

# %%
import gensim
model = gensim.models.Word2Vec.load_word2vec_format("/media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/result_jw_new/myline/model-size/model-all-word2vec", fvocab="/media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/result_jw_new/myline/model-size15/model-all-vocabulary", binary=False)

# %%
for i in [2,5,10,15,20,50,80,100,200,500,1000]:
# for i in [100]:
    print("train-model-size%s"%str(i))
    model = gensim.models.Word2Vec.load_word2vec_format("/media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/result_jw_new/myline/model-size%s/model-all-word2vec"%str(i), fvocab="/media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/result_jw_new/myline/model-size%s/model-all-vocabulary"%str(i), binary=False)
    print(model.most_similar("dynamic.12306.cn",topn=10))
# Out:
# train-model-size2
# [('mb.gk.sdo.com', 1.0000001192092896), ('app.meizu.com', 1.0000001192092896), ('app1.mobage.cn', 1.0), ('bbs.med66.com', 1.0), ('120.202.255.144', 1.0), ('audio.tinghui.fm', 1.0), ('img2.spbo1.com', 1.0), ('218.205.75.59', 1.0), ('www.kkkwkkk.com', 1.0), ('assets.aviary.com.s3.amazonaws.com', 1.0)]
# train-model-size5
# [('img01.mifile.cn', 0.9995959997177124), ('apis.homelink.com.cn', 0.9966810345649719), ('api.letv.com', 0.9966440796852112), ('p.www.xiaomi.com', 0.9955359101295471), ('qd.bs.baidu.com', 0.9946537017822266), ('111.1.16.178', 0.9945303797721863), ('api.steampowered.com', 0.993266761302948), ('112.25.12.136', 0.99294513463974), ('img.mobile.kuxun.cn', 0.9923738837242126), ('www.sn180.com', 0.9915745258331299)]
# train-model-size10
# ...

# %%
model.most_similar("dynamic.12306.cn",topn=10)
# Out:
# [('suanya.cn', 0.8964246511459351),
#  ('www.ikamobile.cn', 0.8952054977416992),
#  ('www.qumaiya.com', 0.8933207988739014),
#  ('ws.qunar.com', 0.8889080286026001),
#  ('223.4.122.119', 0.8735333681106567),
#  ('trainfinder.ikamobile.cn', 0.8612208366394043),
#  ('weather.scheffsblend.com', 0.8489302396774292),
#  ('113.108.239.117', 0.8245449066162109),
#  ('1a.xiao77.bz', 0.8081875443458557),
#  ('chip.static.mediapad.cn', 0.8032176494598389)]

# %%
model.most_similar("cn.patch.battle.net",topn=20)
# Out:
# [('client01.pdl.wow.battlenet.com.cn', 0.9726012945175171),
#  ('client03.pdl.wow.battlenet.com.cn', 0.966675341129303),
#  ('client02.pdl.wow.battlenet.com.cn', 0.9577614068984985),
#  ('cn.launcher.battlenet.com.cn', 0.9420239925384521),
#  ('dist.blizzard.com.edgesuite.net', 0.9354239702224731),
#  ('iir.blizzard.com', 0.9240607023239136),
#  ('zhcn.patch.battle.net', 0.8581839203834534),
#  ('cn-test.patch.battle.net', 0.7930017709732056),
#  ('nwww.baidu.com', 0.740686297416687),
#  ('public-test.patch.battle.net', 0.7305173277854919),
#  ('www.brothersoft.com', 0.6755748391151428),
#  ('client04.pdl.wow.battlenet.com.cn', 0.6583839654922485),
#  ('syndication.exoclick.com', 0.654761791229248),
#  ('i.adingo.jp', 0.6498835682868958),
#  ('e1.extreme-dm.com', 0.6479443311691284),
#  ('img.brothersoft.com', 0.6450714468955994),
#  ('www.rae.es', 0.6449068784713745),
#  ('imgb13.wbiao.cn', 0.6447843909263611),
#  ('ptcms.csdn.net', 0.6441788077354431),
# ...

# %%
model.most_similar("api.jiakaobaodian.com",topn=20)
# Out:
# [('domob.kakamobi.com', 0.765545129776001),
#  ('static.kakamobi.com', 0.7196483016014099),
#  ('www.jiakaobaodian.com', 0.717115581035614),
#  ('ke3.jiakaobaodian.com', 0.7098802328109741),
#  ('ke1.jiakaobaodian.com', 0.6990957260131836),
#  ('ad.kakamobi.com', 0.6983238458633423),
#  ('tuijian.file.kakamobi.com', 0.6362272500991821),
#  ('ad.kakamobi.cn', 0.6286160945892334),
#  ('apps.jiakaobaodian.com', 0.6272850632667542),
#  ('tuijian.kakamobi.com', 0.6272796988487244),
#  ('note.kakamobi.com', 0.6253218650817871),
#  ('file.cloud.kakamobi.com', 0.6228231191635132),
#  ('notice.kakamobi.com', 0.6177820563316345),
#  ('form.kakamobi.com', 0.6047403812408447),
#  ('mucang-logo.oss-cn-hangzhou.aliyuncs.com', 0.5932239294052124),
#  ('mucang.oss.aliyuncs.com', 0.5884891748428345),
#  ('shijia.kakamobi.com', 0.585699737071991),
#  ('mucang.oss-cn-hangzhou.aliyuncs.com', 0.5758064389228821),
#  ('api.tuijian.kakamobi.com', 0.5727900266647339),
# ...

# %%
print(model.vocab['beibeixiong.m.tmall.com'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7c74c6b55356> in <module>()
# ----> 1 print(model.vocab['beibeixiong.m.tmall.com'])
#
# NameError: name 'model' is not defined

# %%
print(model.vocab['cawcki.travelsky.com'])
# Out:
# Vocab(count:20, index:41295)

# %%
model.most_similar("p0.jmstatic.com",topn=20)
# Out:
# [('p3.jmstatic.com', 0.7970021963119507),
#  ('p4.jmstatic.com', 0.7815209627151489),
#  ('p2.jmstatic.com', 0.7772729992866516),
#  ('p1.jmstatic.com', 0.7694284915924072),
#  ('koubei.jumei.com', 0.7686094045639038),
#  ('images2.jumei.com', 0.720537543296814),
#  ('s0.jmstatic.com', 0.706131100654602),
#  ('images.jumei.com', 0.7031669616699219),
#  ('et.jumei.com', 0.660487174987793),
#  ('s1.jmstatic.com', 0.6486424803733826),
#  ('m.jumei.com', 0.6049774885177612),
#  ('mobile.jumei.com', 0.5936969518661499),
#  ('search.jumei.com', 0.5438540577888489),
#  ('cobub.mobile.int.jumei.com', 0.46683722734451294),
#  ('api.group.lmbang.com', 0.45265328884124756),
#  ('iweekapi.com', 0.44682538509368896),
#  ('s.emarbox.com', 0.4394509792327881),
#  ('www.jumei.com', 0.43454957008361816),
#  ('dayima.us', 0.4303697943687439),
#  ('images.sugarlady.com', 0.4302554726600647)]

# %%
model.most_similar("dynamic.12306.cn",topn=20)
# Out:
# [('suanya.cn', 0.5719601511955261),
#  ('www.12306.cn', 0.5228785276412964),
#  ('trainfinder.ikamobile.cn', 0.5180641412734985),
#  ('jt.rsscc.com', 0.5121803879737854),
#  ('www.qumaiya.com', 0.4932478368282318),
#  ('analytics.localytics.com', 0.491361141204834),
#  ('ws.qunar.com', 0.4841668903827667),
#  ('www.557.net.cn', 0.48281607031822205),
#  ('shopmgr.ucai.com', 0.4737396836280823),
#  ('www.web2mi.com', 0.46680787205696106),
#  ('images.rsscc.com', 0.4659736454486847),
#  ('m.virsir.com', 0.44816213846206665),
#  ('download.visionobjects.eu', 0.44476643204689026),
#  ('223.4.122.119', 0.4445369839668274),
#  ('matrix.ikamobile.cn', 0.4317869246006012),
#  ('www.ikamobile.cn', 0.42871925234794617),
#  ('down.lltskb.com', 0.4159358739852905),
#  ('yueche123.net', 0.4095499813556671),
#  ('flowers.snappytouch.com', 0.40429872274398804),
#  ('jimmyxiao.ucoz.com', 0.3948562741279602)]

# %%
model.most_similar("client.qunar.com",topn=20)
# Out:
# [('cheche.qunar.com', 0.5491865873336792),
#  ('car.qunar.com', 0.5471483469009399),
#  ('source.qunar.com', 0.5313616991043091),
#  ('capi.qunar.com', 0.524300217628479),
#  ('qde.qunar.com', 0.5110400319099426),
#  ('userimg.qunar.com', 0.4949049949645996),
#  ('mhotel.qunar.com', 0.46932899951934814),
#  ('live.qunar.com', 0.4291166067123413),
#  ('touch.piao.qunar.com', 0.4279351234436035),
#  ('simg3.qunarzz.com', 0.42690253257751465),
#  ('simg4.qunarzz.com', 0.4161308705806732),
#  ('piao.qunar.com', 0.3910508453845978),
#  ('img1.qunarzz.com', 0.3909468352794647),
#  ('124.14.15.19', 0.35084468126296997),
#  ('applog.camera360.com', 0.3465694785118103),
#  ('lvtu.qunar.com', 0.34102803468704224),
#  ('121.199.12.17', 0.3352585732936859),
#  ('simg2.qunarzz.com', 0.33141443133354187),
#  ('7daysinn.chujian.com', 0.32782647013664246),
#  ('sdk.imap.baidu.com', 0.32355594635009766)]

# %%
model.similarity('dynamic.12306.cn','m.ctrip.com')
# Out:
# 0.15773483061563834

# %%
tsne.fit_transform(final_embeddings)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-15-12e52ae59878> in <module>()
# ----> 1 tsne.fit_transform(final_embeddings)
#
# /home/jw/anaconda3/lib/python3.5/site-packages/sklearn/manifold/t_sne.py in fit_transform(self, X, y)
#     864             Embedding of the training data in low-dimensional space.
#     865         """
# --> 866         embedding = self._fit(X)
#     867         self.embedding_ = embedding
#     868         return self.embedding_
#
# /home/jw/anaconda3/lib/python3.5/site-packages/sklearn/manifold/t_sne.py in _fit(self, X, skip_num_points)
#     716             if self.metric == "euclidean":
#     717                 distances = pairwise_distances(X, metric=self.metric,
# --> 718                                                squared=True)
#     719             else:
# ...

# %%
# Step 6: Visualize the embeddings.
# %pylab inline
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  #in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i,:]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
  plot_only = 300
  final_embeddings=[model[word] for word in model.index2word ]
  low_dim_embs = tsne.fit_transform(final_embeddings)
  labels = [model.index2word[i] for i in range(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print("Please install sklearn and matplotlib to visualize embeddings.")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/jw/anaconda3/lib/python3.5/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['all']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-267-44d0d21ce53b> in <module>()
#      23   plot_only = 300
#      24   final_embeddings=[model[word] for word in model.index2word]
# ---> 25   low_dim_embs = tsne.fit_transform(final_embeddings)
#      26   labels = [model.index2word[i] for i in range(plot_only)]
#      27   plot_with_labels(low_dim_embs, labels)
#
# /home/jw/anaconda3/lib/python3.5/site-packages/sklearn/manifold/t_sne.py in fit_transform(self, X, y)
# ...

# %%
final_embeddings=[model[word] for word in model.index2word if "baidu" in word]

# %%
len(final_embeddings)
# Out:
# 752

# %%
# Step 6: Visualize the embeddings.
# %pylab inline
def plot_with_labels(low_dim_embs):
#   assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  #in inches
  for i in range(len(low_dim_embs)):
    x, y = low_dim_embs[i,:]
    plt.scatter(x, y)
#     plt.annotate(label,
#                  xy=(x, y),
#                  xytext=(5, 2),
#                  textcoords='offset points',
#                  ha='right',
#                  va='bottom')

#   plt.savefig(filename)

try:
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
#   plot_only = 300
  final_embeddings=[model[word] for word in model.index2word if "baidu" in word]
  low_dim_embs = tsne.fit_transform(final_embeddings)
#   labels = [model.index2word[i] for i in range(plot_only)]
  plot_with_labels(low_dim_embs)

except ImportError:
  print("Please install sklearn and matplotlib to visualize embeddings.")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Step 6: Visualize the embeddings.
# %pylab inline
def plot_with_labels(low_dim_embs):
#   assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  #in inches
  for i in range(len(low_dim_embs)):
    x, y = low_dim_embs[i,:]
    plt.scatter(x, y)
#     plt.annotate(label,
#                  xy=(x, y),
#                  xytext=(5, 2),
#                  textcoords='offset points',
#                  ha='right',
#                  va='bottom')

#   plt.savefig(filename)

try:
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(n_components=2, random_state=0, verbose=99, n_iter=500)
#   plot_only = 300
  final_embeddings=[model[word] for word in model.index2word if "baidu" in word]
  low_dim_embs = tsne.fit_transform(final_embeddings)
#   labels = [model.index2word[i] for i in range(plot_only)]
  plot_with_labels(low_dim_embs)

except ImportError:
  print("Please install sklearn and matplotlib to visualize embeddings.")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Computed conditional probabilities for sample 752 / 752
# [t-SNE] Mean sigma: 0.494957
# [t-SNE] Iteration 25: error = 0.9803392, gradient norm = 0.0147406
# [t-SNE] Iteration 50: error = 0.9600864, gradient norm = 0.0130054
# [t-SNE] Iteration 75: error = 0.7535146, gradient norm = 0.0086900
# [t-SNE] Iteration 100: error = 0.7710279, gradient norm = 0.0086259
# [t-SNE] Error after 100 iterations with early exaggeration: 0.771028
# [t-SNE] Iteration 125: error = 0.7141370, gradient norm = 0.0061459
# [t-SNE] Iteration 150: error = 0.7113684, gradient norm = 0.0066087
# [t-SNE] Iteration 175: error = 0.7331705, gradient norm = 0.0053443
# [t-SNE] Iteration 200: error = 0.7203313, gradient norm = 0.0059584
# [t-SNE] Iteration 200: did not make any progress during the last 30 episodes. Finished.
# ...

# %%
# Step 6: Visualize the embeddings.
# %pylab inline
def plot_with_labels(low_dim_embs):
#   assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  #in inches
  for i in range(len(low_dim_embs)):
    x, y = low_dim_embs[i,:]
    plt.scatter(x, y)
#     plt.annotate(label,
#                  xy=(x, y),
#                  xytext=(5, 2),
#                  textcoords='offset points',
#                  ha='right',
#                  va='bottom')

#   plt.savefig(filename)

try:
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
#   plot_only = 300
  final_embeddings=[model[word] for word in model.index2word if "taobao" in word]
  low_dim_embs = tsne.fit_transform(final_embeddings)
#   labels = [model.index2word[i] for i in range(plot_only)]
  plot_with_labels(low_dim_embs)

except ImportError:
  print("Please install sklearn and matplotlib to visualize embeddings.")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Step 6: Visualize the embeddings.
# %pylab inline
def plot_with_labels(low_dim_embs):
#   assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  #in inches
  for i in range(len(low_dim_embs)):
    x, y = low_dim_embs[i,:]
    plt.scatter(x, y)
#     plt.annotate(label,
#                  xy=(x, y),
#                  xytext=(5, 2),
#                  textcoords='offset points',
#                  ha='right',
#                  va='bottom')

#   plt.savefig(filename)

try:
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(n_components=2, random_state=0, verbose=99, n_iter=500)
#   plot_only = 300
  final_embeddings=[model[word] for word in model.index2word if "taobao" in word]
  low_dim_embs = tsne.fit_transform(final_embeddings)
#   labels = [model.index2word[i] for i in range(plot_only)]
  plot_with_labels(low_dim_embs)

except ImportError:
  print("Please install sklearn and matplotlib to visualize embeddings.")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Computed conditional probabilities for sample 600 / 600
# [t-SNE] Mean sigma: 0.314987
# [t-SNE] Iteration 25: error = 1.0371580, gradient norm = 0.0181394
# [t-SNE] Iteration 50: error = 1.0688167, gradient norm = 0.0160649
# [t-SNE] Iteration 75: error = 0.7836064, gradient norm = 0.0103521
# [t-SNE] Iteration 100: error = 0.8090037, gradient norm = 0.0088629
# [t-SNE] Error after 100 iterations with early exaggeration: 0.809004
# [t-SNE] Iteration 125: error = 0.7377566, gradient norm = 0.0045812
# [t-SNE] Iteration 150: error = 0.7387910, gradient norm = 0.0040942
# [t-SNE] Iteration 175: error = 0.7383110, gradient norm = 0.0041109
# [t-SNE] Iteration 175: did not make any progress during the last 30 episodes. Finished.
# [t-SNE] Error after 175 iterations: 0.738311

# %%
# Step 6: Visualize the embeddings.
# %pylab inline
def plot_with_labels(low_dim_embs):
#   assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  #in inches
  for i in range(len(low_dim_embs)):
    x, y = low_dim_embs[i,:]
    plt.scatter(x, y)
#     plt.annotate(label,
#                  xy=(x, y),
#                  xytext=(5, 2),
#                  textcoords='offset points',
#                  ha='right',
#                  va='bottom')

#   plt.savefig(filename)

try:
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(n_components=2, random_state=0, verbose=99, n_iter=500)
#   plot_only = 300
  final_embeddings=[model[word] for word in model.index2word if "qq" in word]
  low_dim_embs = tsne.fit_transform(final_embeddings)
#   labels = [model.index2word[i] for i in range(plot_only)]
  plot_with_labels(low_dim_embs)

except ImportError:
  print("Please install sklearn and matplotlib to visualize embeddings.")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# [t-SNE] Computing pairwise distances...
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3255
# [t-SNE] Computed conditional probabilities for sample 2000 / 3255
# [t-SNE] Computed conditional probabilities for sample 3000 / 3255
# [t-SNE] Computed conditional probabilities for sample 3255 / 3255
# [t-SNE] Mean sigma: 0.293064
# [t-SNE] Iteration 25: error = 1.3871461, gradient norm = 0.0095720
# [t-SNE] Iteration 50: error = 1.3003937, gradient norm = 0.0076561
# [t-SNE] Iteration 75: error = 1.0554551, gradient norm = 0.0030860
# [t-SNE] Iteration 100: error = 1.0235846, gradient norm = 0.0035935
# [t-SNE] Error after 100 iterations with early exaggeration: 1.023585
# [t-SNE] Iteration 125: error = 0.9662374, gradient norm = 0.0025729
# [t-SNE] Iteration 150: error = 0.9535961, gradient norm = 0.0031006
# ...

# %%
# Step 6: Visualize the embeddings.
# %pylab inline
def plot_with_labels(low_dim_embs):
#   assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  #in inches
  for i in range(len(low_dim_embs)):
    x, y = low_dim_embs[i,:]
    plt.scatter(x, y)
#     plt.annotate(label,
#                  xy=(x, y),
#                  xytext=(5, 2),
#                  textcoords='offset points',
#                  ha='right',
#                  va='bottom')

#   plt.savefig(filename)

try:
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
#   plot_only = 300
  final_embeddings=[model[word] for word in model.index2word if "qq" in word]
  low_dim_embs = tsne.fit_transform(final_embeddings)
#   labels = [model.index2word[i] for i in range(plot_only)]
  plot_with_labels(low_dim_embs)

except ImportError:
  print("Please install sklearn and matplotlib to visualize embeddings.")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Step 6: Visualize the embeddings.
# %pylab inline
def plot_with_labels(low_dim_embs):
#   assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  #in inches
  for i in range(len(low_dim_embs)):
    x, y = low_dim_embs[i,:]
    plt.scatter(x, y)
#     plt.annotate(label,
#                  xy=(x, y),
#                  xytext=(5, 2),
#                  textcoords='offset points',
#                  ha='right',
#                  va='bottom')

#   plt.savefig(filename)

try:
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
#   plot_only = 300
  final_embeddings=[model[word] for word in model.index2word if "uc" in word]
  low_dim_embs = tsne.fit_transform(final_embeddings)
#   labels = [model.index2word[i] for i in range(plot_only)]
  plot_with_labels(low_dim_embs)

except ImportError:
  print("Please install sklearn and matplotlib to visualize embeddings.")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Step 6: Visualize the embeddings.
# %pylab inline
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  #in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i,:]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2)
  plot_only = 300
  final_embeddings=[model[word] for word in model.index2word[:300] ]
  low_dim_embs = tsne.fit_transform(final_embeddings)
  labels = [model.index2word[i] for i in range(plot_only)]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print("Please install sklearn and matplotlib to visualize embeddings.")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# Step 6: Visualize the embeddings.
# %pylab inline
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  #in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i,:]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
  plot_only = 100
  final_embeddings=[model[word] for word in model.index2word[:100] if "qq" in word ]
  low_dim_embs = tsne.fit_transform(final_embeddings)
  labels = [ word for word in  model.index2word[:100] if "qq" in word]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print("Please install sklearn and matplotlib to visualize embeddings.")
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
len([ word for word in  model.index2word if "qq" in word])
# Out:
# 3255

# %%
# Step 6: Visualize the embeddings.
# %pylab inline
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
  assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
  plt.figure(figsize=(18, 18))  #in inches
  for i, label in enumerate(labels):
    x, y = low_dim_embs[i,:]
    plt.scatter(x, y)
    plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

  plt.savefig(filename)

try:
  from sklearn.manifold import TSNE
  import matplotlib.pyplot as plt

  tsne = TSNE(perplexity=30)
  plot_only = 3000
  key="app"
  final_embeddings=[model[word] for word in model.index2word[:plot_only] if key in word ]
#   final_embeddings=[model[word] for word in model.index2word if key in word ]
  print(len(final_embeddings))
  low_dim_embs = tsne.fit_transform(final_embeddings)
  labels = [ word for word in  model.index2word[:plot_only] if key in word]
  plot_with_labels(low_dim_embs, labels)

except ImportError:
  print("Please install sklearn and matplotlib to visualize embeddings.")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# 148

# %%
plot_only
# Out:
# 300

# %%
doamin="www.baidu.com"
key = "baidu"
topn=10
len([word for word in  model.most_similar(doamin,topn=topn) if key in word[0]])
# Out:
# 4

# %%
alibaba=["taobao","tmall","etao","alipay","ali"]
baidu=["baidu"]
tencent=["qq","weixin","qlogo","qpic","gtimg"]
sina=["sina","weibo"]
domain_keys=[
            ("api.m.taobao.com",alibaba),
          ("m.baidu.com",baidu),
            ("short.weixin.qq.com",tencent),
    ("wbapp.mobile.sina.cn",sina)
            ]
# def get_Precision(topn,)
topn=10

all=[]
all_num=topn*len(domain_keys)
for i in domain_keys:
    for j in i[1]:
        all=all+[word[0] for word in  model.most_similar(i[0],topn=topn) if j in word[0]]
len(set(all))/all_num
# Out:
# 0.9

# %%
company_domain_file="/media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/result_jw/model/domain-cluster/sina.txt"
domain_keys=[]
company=sina
with open(company_domain_file ,mode='r',encoding="utf-8") as infile:
    line_limit=10
    i=0
    for line in infile:
        i=i+1
        domain_keys=[(line.split(" ")[0],company)]+domain_keys
        if i==line_limit:
            break
            
all_num=topn*len(domain_keys)
for i in domain_keys:
    for j in i[1]:
        all=all+[word[0] for word in  model.most_similar(i[0],topn=topn) if j in word[0]]
len(set(all))/all_num
# Out:
# 0.48

# %%
company=tencent
company_domain_file="/media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/result_jw/model/domain-cluster/"+company[0]+".txt"
domain_keys=[]
with open(company_domain_file ,mode='r',encoding="utf-8") as infile:
    line_limit=6
    i=0
    for line in infile:
        i=i+1
        domain_keys=[(line.split(" ")[0],company)]+domain_keys
        if i==line_limit:
            break
            
all_num=topn*len(domain_keys)
all=[]
for i in domain_keys:
    for j in i[1]:
#         print(j)
        all=all+[word[0] for word in  model.most_similar(i[0],topn=topn) if j in word[0]]
len(set(all))/all_num

# %%
company=tencent
company_domain_file="/media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/result_jw/model/domain-cluster/"+company[0]+".txt"
line_limit=6
for line_limit in range(1,10):
    domain_keys=[]
    with open(company_domain_file ,mode='r',encoding="utf-8") as infile:
        line_limit=line_limit
        print(line_limit)
        i=0
        for line in infile:
            i=i+1
            domain_keys=[(line.split(" ")[0],company)]+domain_keys
            if i==line_limit:
                break

    all_num=topn*len(domain_keys)
    all=[]
    for i in domain_keys:
        for j in i[1]:
    #         print(j)
            all=all+[word[0] for word in  model.most_similar(i[0],topn=topn) if j in word[0]]
    print(line_limit,"---->>>",len(set(all))/all_num)
# Out:
# 1
# 1 ---->>> 0.9
# 2
# 2 ---->>> 0.8
# 3
# 3 ---->>> 0.5666666666666667
# 4
# 4 ---->>> 0.525
# 5
# 5 ---->>> 0.44
# 6
# 6 ---->>> 0.4166666666666667
# 7
# 7 ---->>> 0.38571428571428573
# 8
# 8 ---->>> 0.3875
# 9
# 9 ---->>> 0.4222222222222222

# %%
company=tencent
company_domain_file="/media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/result_jw/model/domain-cluster/"+company[0]+".txt"
topn=10
import matplotlib.pyplot as plt
x=[]
y=[]
for line_limit in range(1,30):
    domain_keys=[]
    with open(company_domain_file ,mode='r',encoding="utf-8") as infile:
        line_limit=line_limit
        print(line_limit)
        i=0
        for line in infile:
            i=i+1
            domain_keys=[(line.split(" ")[0],company)]+domain_keys
            if i==line_limit:
                break
    print(len(domain_keys))
    all_num=topn*len(domain_keys)
    all=[]
    for i in domain_keys:
        for j in i[1]:
    #         print(j)
            all=all+[word[0] for word in  model.most_similar(i[0],topn=topn) if j in word[0]]
    print(line_limit,"---->>>",len(set(all))/all_num)
    x.append(line_limit)
    y.append(len(set(all))/all_num)
plt.plot(x, y)
plt.show()
# Out:
# 1
# 1
# 1 ---->>> 0.9
# 2
# 2
# 2 ---->>> 0.8
# 3
# 3
# 3 ---->>> 0.5666666666666667
# 4
# 4
# 4 ---->>> 0.525
# 5
# 5
# 5 ---->>> 0.44
# 6
# 6
# 6 ---->>> 0.4166666666666667
# 7
# 7
# 7 ---->>> 0.38571428571428573
# 8
# 8
# 8 ---->>> 0.3875
# 9
# 9
# 9 ---->>> 0.4222222222222222
# 10
# 10
# 10 ---->>> 0.47
# 11
# 11
# 11 ---->>> 0.43636363636363634
# 12
# 12
# 12 ---->>> 0.425
# 13
# 13
# 13 ---->>> 0.4307692307692308
# 14
# 14
# 14 ---->>> 0.42857142857142855
# 15
# 15
# 15 ---->>> 0.43333333333333335
# 16
# 16
# 16 ---->>> 0.4375
# 17
# 17
# 17 ---->>> 0.45294117647058824
# 18
# 18
# 18 ---->>> 0.42777777777777776
# 19
# 19
# 19 ---->>> 0.41578947368421054
# 20
# 20
# 20 ---->>> 0.42
# 21
# 21
# 21 ---->>> 0.4142857142857143
# 22
# 22
# 22 ---->>> 0.43636363636363634
# 23
# 23
# 23 ---->>> 0.4217391304347826
# 24
# 24
# 24 ---->>> 0.4166666666666667
# 25
# 25
# 25 ---->>> 0.436
# 26
# 26
# 26 ---->>> 0.4307692307692308
# 27
# 27
# 27 ---->>> 0.43703703703703706
# 28
# 28
# ...

# %%
topn
# Out:
# 10

# %%
company=baidu
company_domain_file="/media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/result_jw/model/domain-cluster/"+company[0]+".txt"
topn=10
import matplotlib.pyplot as plt
x=[]
y=[]
for line_limit in range(1,30):
    domain_keys=[]
    with open(company_domain_file ,mode='r',encoding="utf-8") as infile:
        line_limit=line_limit
        print(line_limit)
        i=0
        for line in infile:
            i=i+1
            domain_keys=[(line.split(" ")[0],company)]+domain_keys
            if i==line_limit:
                break
    print(len(domain_keys))
    all_num=topn*len(domain_keys)
    all=[]
    for i in domain_keys:
        for j in i[1]:
    #         print(j)
            all=all+[word[0] for word in  model.most_similar(i[0],topn=topn) if j in word[0]]
    print(line_limit,"---->>>",len(set(all))/all_num)
    x.append(line_limit)
    y.append(len(set(all))/all_num)
plt.plot(x, y)
plt.show()
# Out:
# 1
# 1
# 1 ---->>> 0.8
# 2
# 2
# 2 ---->>> 0.55
# 3
# 3
# 3 ---->>> 0.5
# 4
# 4
# 4 ---->>> 0.4
# 5
# 5
# 5 ---->>> 0.46
# 6
# 6
# 6 ---->>> 0.4
# 7
# 7
# 7 ---->>> 0.4142857142857143
# 8
# 8
# 8 ---->>> 0.3875
# 9
# 9
# 9 ---->>> 0.36666666666666664
# 10
# 10
# 10 ---->>> 0.38
# 11
# 11
# 11 ---->>> 0.4
# 12
# 12
# 12 ---->>> 0.38333333333333336
# 13
# 13
# 13 ---->>> 0.35384615384615387
# 14
# 14
# 14 ---->>> 0.32857142857142857
# 15
# 15
# 15 ---->>> 0.31333333333333335
# 16
# 16
# 16 ---->>> 0.3
# 17
# 17
# 17 ---->>> 0.2823529411764706
# 18
# 18
# 18 ---->>> 0.2722222222222222
# 19
# 19
# 19 ---->>> 0.2578947368421053
# 20
# 20
# 20 ---->>> 0.245
# 21
# 21
# 21 ---->>> 0.23809523809523808
# 22
# 22
# 22 ---->>> 0.24545454545454545
# 23
# 23
# 23 ---->>> 0.23478260869565218
# 24
# 24
# 24 ---->>> 0.2375
# 25
# 25
# 25 ---->>> 0.232
# 26
# 26
# 26 ---->>> 0.23846153846153847
# 27
# 27
# 27 ---->>> 0.22962962962962963
# 28
# 28
# 28 ---->>> 0.225
# 29
# 29
# ...

# %%
company=sina
company_domain_file="/media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/result_jw/model/domain-cluster/"+company[0]+".txt"
topn=10
import matplotlib.pyplot as plt
x=[]
y=[]
for line_limit in range(1,30):
    domain_keys=[]
    with open(company_domain_file ,mode='r',encoding="utf-8") as infile:
        line_limit=line_limit
        print(line_limit)
        i=0
        for line in infile:
            i=i+1
            domain_keys=[(line.split(" ")[0],company)]+domain_keys
            if i==line_limit:
                break
    print(len(domain_keys))
    all_num=topn*len(domain_keys)
    all=[]
    for i in domain_keys:
        for j in i[1]:
    #         print(j)
            all=all+[word[0] for word in  model.most_similar(i[0],topn=topn) if j in word[0]]
    print(line_limit,"---->>>",len(set(all))/all_num)
    x.append(line_limit)
    y.append(len(set(all))/all_num)
plt.plot(x, y)
plt.show()
