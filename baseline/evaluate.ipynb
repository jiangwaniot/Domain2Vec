# %%
date = 20131228
one_model_path = os.path.join("/media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw",str(date)+"/ModelResult/model-size%s"%str(100))
one_model_path
# Out:
# '/media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131228/ModelResult/model-size100'

# %%
import gensim
import shutil 
import numpy as np
import numpy as np
from sklearn.linear_model import SGDClassifier
from sklearn import metrics
from sklearn.cross_validation import cross_val_score

for date in [20131228]:
    # for s in [1,2,3,5,7,9,13,15,20,30,50]:
#     for i in [2,4,8,16,32,64,128,256,512]:
    for i in [2]:
        print("evaluate model size:%s"%str(i))
        one_model_path = os.path.join("/media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw",str(date)+"/ModelResult/model-size%s"%str(i))
        model = gensim.models.Word2Vec.load_word2vec_format(one_model_path+"/model-all-word2vec", fvocab=one_model_path+"/model-all-vocabulary", binary=False)
        count = 400
        baidu_embeddings = [model[word] for word in model.index2word  if "baidu" in word]
        taobao_embeddings = [model[word] for word in model.index2word  if "taobao" in word]
        qq_embeddings = [model[word] for word in model.index2word  if "qq" in word]      
        sina_embeddings = [model[word] for word in model.index2word  if "sina" in word]
        wangyi_embeddings = [model[word] for word in model.index2word  if "163" in word]
#         uc_embeddings = [model[word] for word in model.index2word  if "uc" in word]

        y = np.array([0 for i in range(count)]+[1 for i in range(count)]+[2 for i in range(count)]+[3 for i in range(count)]+[4 for i in range(count)])
        X = baidu_embeddings[:count]+taobao_embeddings[:count]+qq_embeddings[:count] + sina_embeddings[:count]+wangyi_embeddings[:count]

        from sklearn.cross_validation import train_test_split
        x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=234)


        result= [] 
        SVM=SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, n_iter=20, random_state=74)
        scores = cross_val_score(SVM, X, y, cv=10,scoring='accuracy')
        result.append("accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))

        scores = cross_val_score(SVM, X, y, cv=10,scoring='precision_micro')
        result.append("precision_micro: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
        scores = cross_val_score(SVM, X, y, cv=10,scoring='precision_macro')
        result.append("precision_macro: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
        scores = cross_val_score(SVM, X, y, cv=10,scoring='recall_micro')
        result.append("recall_micro: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
        scores = cross_val_score(SVM, X, y, cv=10,scoring='recall_macro')
        result.append("recall_macro: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))

        scores = cross_val_score(SVM, X, y, cv=10,scoring='f1_micro')                                      
        result.append("f1_micro: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))

        scores = cross_val_score(SVM, X, y, cv=10,scoring='f1_macro')
        result.append("f1_macro: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))
        print(result)
#     clf_SVM = SVM.fit(x_train, y_train)
#     doc_class_predicted = clf_SVM.predict(x_test)
#     print(np.mean(doc_class_predicted == y_test))
#     print(metrics.classification_report(y_test, doc_class_predicted))
# Out:
# evaluate model size:2
# /home/jw/anaconda3/lib/python3.5/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/jw/anaconda3/lib/python3.5/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/jw/anaconda3/lib/python3.5/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/jw/anaconda3/lib/python3.5/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
# ...

# %%
cross_val_score?

# %%
import gensim
import shutil 
import numpy as np
import numpy as np
from sklearn.linear_model import SGDClassifier
from sklearn import metrics
from sklearn.cross_validation import cross_val_score

for date in [20131228]:
    # for s in [1,2,3,5,7,9,13,15,20,30,50]:
    for i in [2,4,8,16,32,64,128,256,512]:
        print("evaluate model size:%s"%str(i))
        one_model_path = os.path.join("/media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw",str(date)+"/ModelResult/model-size%s"%str(i))
        model = gensim.models.Word2Vec.load_word2vec_format(one_model_path+"/model-all-word2vec", fvocab=one_model_path+"/model-all-vocabulary", binary=False)
        count = 400
        shop_embeddings = [model[word] for word in model.index2word  if "shop" in word]
        map_embeddings = [model[word] for word in model.index2word  if "map" in word ]
        media_embeddings = [model[word] for word in model.index2word  if "mail" in word]
        game_embeddings = [model[word] for word in model.index2word  if "game" in word]

        y = np.array([0 for i in range(count)]+[1 for i in range(count)]+[2 for i in range(count)]+[3 for i in range(count)])
        X = shop_embeddings[:count]+map_embeddings[:count]+media_embeddings[:count]+game_embeddings[:count]

        from sklearn.cross_validation import train_test_split
        x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=234)


        SVM=SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, n_iter=20, random_state=42)
        scores = cross_val_score(SVM, X, y, cv=10,scoring='f1_macro')
        print(scores)                                              
        print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2),"\n")
#     clf_SVM = SVM.fit(x_train, y_train)
#     doc_class_predicted = clf_SVM.predict(x_test)
#     print(np.mean(doc_class_predicted == y_test))
#     print(metrics.classification_report(y_test, doc_class_predicted))

# %% [markdown]
# # result

# %%
for date in [20131228, 20131229,20131230,20131231,20140101,20140102,20140103]:
    for modelpath in ["keep-cbow", "keep-skip-gram", "remove-cbow", "remove-skip-gram"]:
        model_path = "/media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/%s/model-compare/%s"%(str(date), str(modelpath))
        print(model_path)
        print(os.path.exists(model_path))
# Out:
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131228/model-compare/keep-cbow
# True
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131228/model-compare/keep-skip-gram
# True
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131228/model-compare/remove-cbow
# True
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131228/model-compare/remove-skip-gram
# True
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131229/model-compare/keep-cbow
# True
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131229/model-compare/keep-skip-gram
# True
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131229/model-compare/remove-cbow
# True
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131229/model-compare/remove-skip-gram
# True
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131230/model-compare/keep-cbow
# True
# ...

# %%
alldate_result = {}
for date in [20131228, 20131229,20131230,20131231,20140101,20140102,20140103]:
    results ={}
    for modelpath in ["keep-cbow", "keep-skip-gram", "remove-cbow", "remove-skip-gram"]:
        model_path = "/media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/%s/model-compare/%s"%(str(date), str(modelpath))
        print(model_path)
        fname = os.path.join(model_path, "model-all-word2vec")
        fvocab = os.path.join(model_path, "model-all-vocabulary")
        model = gensim.models.Word2Vec.load_word2vec_format(fname, fvocab=fvocab, binary=False)

        count = 400
        baidu_embeddings = [model[word] for word in model.index2word  if "baidu" in word]
        taobao_embeddings = [model[word] for word in model.index2word  if "taobao" in word]
        qq_embeddings = [model[word] for word in model.index2word  if "qq" in word]      
        sina_embeddings = [model[word] for word in model.index2word  if "sina" in word]
        wangyi_embeddings = [model[word] for word in model.index2word  if "163" in word]
    #         uc_embeddings = [model[word] for word in model.index2word  if "uc" in word]

        y = np.array([0 for i in range(count)]+[1 for i in range(count)]+[2 for i in range(count)]+[3 for i in range(count)]+[4 for i in range(count)])
        X = baidu_embeddings[:count]+taobao_embeddings[:count]+qq_embeddings[:count] + sina_embeddings[:count]+wangyi_embeddings[:count]

        from sklearn.cross_validation import train_test_split
        x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=234)

        result= [] 
        SVM=SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, n_iter=20, random_state=74)

        scores = cross_val_score(SVM, X, y, cv=10,scoring='accuracy')
        result.append("accuracy: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))

        scores = cross_val_score(SVM, X, y, cv=10,scoring='precision_micro')
        result.append("precision_micro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
        scores = cross_val_score(SVM, X, y, cv=10,scoring='precision_macro')
        result.append("precision_macro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
        scores = cross_val_score(SVM, X, y, cv=10,scoring='recall_micro')
        result.append("recall_micro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
        scores = cross_val_score(SVM, X, y, cv=10,scoring='recall_macro')
        result.append("recall_macro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))

        scores = cross_val_score(SVM, X, y, cv=10,scoring='f1_micro')                                      
        result.append("f1_micro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
        scores = cross_val_score(SVM, X, y, cv=10,scoring='f1_macro')
        result.append("f1_macro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))

    #     print(result)
        results[modelpath] = result
    alldate_result[date] = results
print(alldate_result)
# Out:
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131228/model-compare/keep-cbow
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131228/model-compare/keep-skip-gram
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131228/model-compare/remove-cbow
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131228/model-compare/remove-skip-gram
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131229/model-compare/keep-cbow
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131229/model-compare/keep-skip-gram
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131229/model-compare/remove-cbow
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131229/model-compare/remove-skip-gram
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131230/model-compare/keep-cbow
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131230/model-compare/keep-skip-gram
# ...

# %%
alldate_result = {}
for date in [20131228, 20131229,20131230,20131231,20140101,20140102,20140103]:
    results ={}
    for modelpath in ["keep-cbow", "keep-skip-gram", "remove-cbow", "remove-skip-gram"]:
        model_path = "/media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/%s/model-compare/%s"%(str(date), str(modelpath))
        print(model_path)
        fname = os.path.join(model_path, "model-all-word2vec")
        fvocab = os.path.join(model_path, "model-all-vocabulary")
        model = gensim.models.Word2Vec.load_word2vec_format(fname, fvocab=fvocab, binary=False)
        count = 400
        shop_embeddings = [model[word] for word in model.index2word  if "shop" in word]
        map_embeddings = [model[word] for word in model.index2word  if "map" in word ]
        media_embeddings = [model[word] for word in model.index2word  if "mail" in word]
        game_embeddings = [model[word] for word in model.index2word  if "game" in word]
        y = np.array([0 for i in range(count)]+[1 for i in range(count)]+[2 for i in range(count)]+[3 for i in range(count)])
        X = shop_embeddings[:count]+map_embeddings[:count]+media_embeddings[:count]+game_embeddings[:count]

        from sklearn.cross_validation import train_test_split
        x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=234)

        result= [] 
        SVM=SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, n_iter=20, random_state=74)

        scores = cross_val_score(SVM, X, y, cv=10,scoring='accuracy')
        result.append("accuracy: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))

        scores = cross_val_score(SVM, X, y, cv=10,scoring='precision_micro')
        result.append("precision_micro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
        scores = cross_val_score(SVM, X, y, cv=10,scoring='precision_macro')
        result.append("precision_macro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
        scores = cross_val_score(SVM, X, y, cv=10,scoring='recall_micro')
        result.append("recall_micro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
        scores = cross_val_score(SVM, X, y, cv=10,scoring='recall_macro')
        result.append("recall_macro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))

        scores = cross_val_score(SVM, X, y, cv=10,scoring='f1_micro')                                      
        result.append("f1_micro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
        scores = cross_val_score(SVM, X, y, cv=10,scoring='f1_macro')
        result.append("f1_macro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
    
    #     print(result)
        results[modelpath] = result
    alldate_result[date] = results
print(alldate_result)
# Out:
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131228/model-compare/keep-cbow
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131228/model-compare/keep-skip-gram
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131228/model-compare/remove-cbow
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131228/model-compare/remove-skip-gram
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131229/model-compare/keep-cbow
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131229/model-compare/keep-skip-gram
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131229/model-compare/remove-cbow
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131229/model-compare/remove-skip-gram
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131230/model-compare/keep-cbow
# /media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131230/model-compare/keep-skip-gram
# ...

# %% [markdown]
# # effrec of D and W

# %%
results ={}
for s in [2,4,8,16,32,64,128,256,512,1024,2048]:
#     print("train-repeat-model-size%s"%str(s))
    model_path = "/media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131228/ModelResult/model-size%s"%str(s)
    print(os.path.split(model_path)[1])
    fname = os.path.join(model_path, "model-all-word2vec")
    fvocab = os.path.join(model_path, "model-all-vocabulary")
    model = gensim.models.Word2Vec.load_word2vec_format(fname, fvocab=fvocab, binary=False)

    count = 400
    baidu_embeddings = [model[word] for word in model.index2word  if "baidu" in word]
    taobao_embeddings = [model[word] for word in model.index2word  if "taobao" in word]
    qq_embeddings = [model[word] for word in model.index2word  if "qq" in word]      
    sina_embeddings = [model[word] for word in model.index2word  if "sina" in word]
    wangyi_embeddings = [model[word] for word in model.index2word  if "163" in word]

    y = np.array([0 for i in range(count)]+[1 for i in range(count)]+[2 for i in range(count)]+[3 for i in range(count)]+[4 for i in range(count)])
    X = baidu_embeddings[:count]+taobao_embeddings[:count]+qq_embeddings[:count] + sina_embeddings[:count]+wangyi_embeddings[:count]

    from sklearn.cross_validation import train_test_split
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=234)
    
    result= [] 
    SVM=SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, n_iter=20, random_state=74)
    
    scores = cross_val_score(SVM, X, y, cv=10,scoring='accuracy')
    result.append("accuracy: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))

    scores = cross_val_score(SVM, X, y, cv=10,scoring='precision_micro')
    result.append("precision_micro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
    scores = cross_val_score(SVM, X, y, cv=10,scoring='precision_macro')
    result.append("precision_macro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
    scores = cross_val_score(SVM, X, y, cv=10,scoring='recall_micro')
    result.append("recall_micro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
    scores = cross_val_score(SVM, X, y, cv=10,scoring='recall_macro')
    result.append("recall_macro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))

    scores = cross_val_score(SVM, X, y, cv=10,scoring='f1_micro')                                      
    result.append("f1_micro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
    scores = cross_val_score(SVM, X, y, cv=10,scoring='f1_macro')
    result.append("f1_macro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))

    print(result)
    results[os.path.split(model_path)[1]] = result
print(results)
# Out:
# model-size2
# /home/jw/anaconda3/lib/python3.5/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/jw/anaconda3/lib/python3.5/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/jw/anaconda3/lib/python3.5/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/jw/anaconda3/lib/python3.5/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...

# %%
results ={} 
for s in [2,4,8,16,32,64,128,256,512,1024,2048]:
#     print("train-repeat-model-size%s"%str(s))
    model_path = "/media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131228/ModelResult/model-size%s"%str(s)
    print(os.path.split(model_path)[1])
    fname = os.path.join(model_path, "model-all-word2vec")
    fvocab = os.path.join(model_path, "model-all-vocabulary")
    model = gensim.models.Word2Vec.load_word2vec_format(fname, fvocab=fvocab, binary=False)

    count = 400
    shop_embeddings = [model[word] for word in model.index2word  if "shop" in word]
    map_embeddings = [model[word] for word in model.index2word  if "map" in word ]
    media_embeddings = [model[word] for word in model.index2word  if "mail" in word]
    game_embeddings = [model[word] for word in model.index2word  if "game" in word]
    y = np.array([0 for i in range(count)]+[1 for i in range(count)]+[2 for i in range(count)]+[3 for i in range(count)])
    X = shop_embeddings[:count]+map_embeddings[:count]+media_embeddings[:count]+game_embeddings[:count]

    from sklearn.cross_validation import train_test_split
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=234)
    
    result= [] 
    SVM=SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, n_iter=20, random_state=74)
    
    scores = cross_val_score(SVM, X, y, cv=10,scoring='accuracy')
    result.append("accuracy: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))

    scores = cross_val_score(SVM, X, y, cv=10,scoring='precision_micro')
    result.append("precision_micro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
    scores = cross_val_score(SVM, X, y, cv=10,scoring='precision_macro')
    result.append("precision_macro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
    scores = cross_val_score(SVM, X, y, cv=10,scoring='recall_micro')
    result.append("recall_micro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
    scores = cross_val_score(SVM, X, y, cv=10,scoring='recall_macro')
    result.append("recall_macro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))

    scores = cross_val_score(SVM, X, y, cv=10,scoring='f1_micro')                                      
    result.append("f1_micro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
    scores = cross_val_score(SVM, X, y, cv=10,scoring='f1_macro')
    result.append("f1_macro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
    
    results[os.path.split(model_path)[1]] = result
print(results)
# Out:
# model-size2
# /home/jw/anaconda3/lib/python3.5/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/jw/anaconda3/lib/python3.5/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/jw/anaconda3/lib/python3.5/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# /home/jw/anaconda3/lib/python3.5/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# ...

# %%
results ={}
for w in [2,4,8,16,32,64, 128,256,512,1024]:
#     print("train-repeat-model-size%s"%str(s))
    model_path = "/media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131228/ModelResult/model-window%s"%str(w)
    print(os.path.split(model_path)[1])
    fname = os.path.join(model_path, "model-all-word2vec")
    fvocab = os.path.join(model_path, "model-all-vocabulary")
    model = gensim.models.Word2Vec.load_word2vec_format(fname, fvocab=fvocab, binary=False)

    count = 400
    baidu_embeddings = [model[word] for word in model.index2word  if "baidu" in word]
    taobao_embeddings = [model[word] for word in model.index2word  if "taobao" in word]
    qq_embeddings = [model[word] for word in model.index2word  if "qq" in word]      
    sina_embeddings = [model[word] for word in model.index2word  if "sina" in word]
    wangyi_embeddings = [model[word] for word in model.index2word  if "163" in word]

    y = np.array([0 for i in range(count)]+[1 for i in range(count)]+[2 for i in range(count)]+[3 for i in range(count)]+[4 for i in range(count)])
    X = baidu_embeddings[:count]+taobao_embeddings[:count]+qq_embeddings[:count] + sina_embeddings[:count]+wangyi_embeddings[:count]

    from sklearn.cross_validation import train_test_split
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=234)
    
    result= [] 
    SVM=SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, n_iter=20, random_state=74)
    
    scores = cross_val_score(SVM, X, y, cv=10,scoring='accuracy')
    result.append("accuracy: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))

    scores = cross_val_score(SVM, X, y, cv=10,scoring='precision_micro')
    result.append("precision_micro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
    scores = cross_val_score(SVM, X, y, cv=10,scoring='precision_macro')
    result.append("precision_macro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
    scores = cross_val_score(SVM, X, y, cv=10,scoring='recall_micro')
    result.append("recall_micro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
    scores = cross_val_score(SVM, X, y, cv=10,scoring='recall_macro')
    result.append("recall_macro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))

    scores = cross_val_score(SVM, X, y, cv=10,scoring='f1_micro')                                      
    result.append("f1_micro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
    scores = cross_val_score(SVM, X, y, cv=10,scoring='f1_macro')
    result.append("f1_macro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
    
    results[os.path.split(model_path)[1]] = result
print(results)
# Out:
# model-window2
# model-window4
# model-window8
# model-window16
# model-window32
# model-window64
# model-window128
# model-window256
# model-window512
# model-window1024
# ...

# %%
results ={}
for w in [2,4,8,16,32,64, 128,256,512,1024]:
#     print("train-repeat-model-size%s"%str(s))
    model_path = "/media/jw/5dccc50e-7c13-4186-bf6b-d894f02410be/domain2vec_jw/20131228/ModelResult/model-window%s"%str(w)
    print(os.path.split(model_path)[1])
    fname = os.path.join(model_path, "model-all-word2vec")
    fvocab = os.path.join(model_path, "model-all-vocabulary")
    model = gensim.models.Word2Vec.load_word2vec_format(fname, fvocab=fvocab, binary=False)

    count = 400
    shop_embeddings = [model[word] for word in model.index2word  if "shop" in word]
    map_embeddings = [model[word] for word in model.index2word  if "map" in word ]
    media_embeddings = [model[word] for word in model.index2word  if "mail" in word]
    game_embeddings = [model[word] for word in model.index2word  if "game" in word]
    y = np.array([0 for i in range(count)]+[1 for i in range(count)]+[2 for i in range(count)]+[3 for i in range(count)])
    X = shop_embeddings[:count]+map_embeddings[:count]+media_embeddings[:count]+game_embeddings[:count]

    from sklearn.cross_validation import train_test_split
    x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=234)
    
    result= [] 
    SVM=SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, n_iter=20, random_state=74)
    
    scores = cross_val_score(SVM, X, y, cv=10,scoring='accuracy')
    result.append("accuracy: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))

    scores = cross_val_score(SVM, X, y, cv=10,scoring='precision_micro')
    result.append("precision_micro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
    scores = cross_val_score(SVM, X, y, cv=10,scoring='precision_macro')
    result.append("precision_macro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
    scores = cross_val_score(SVM, X, y, cv=10,scoring='recall_micro')
    result.append("recall_micro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
    scores = cross_val_score(SVM, X, y, cv=10,scoring='recall_macro')
    result.append("recall_macro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))

    scores = cross_val_score(SVM, X, y, cv=10,scoring='f1_micro')                                      
    result.append("f1_micro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
    scores = cross_val_score(SVM, X, y, cv=10,scoring='f1_macro')
    result.append("f1_macro: %0.3f (+/- %0.3f)" % (scores.mean(), scores.std() * 2))
    
    results[os.path.split(model_path)[1]] = result
print(results)
# Out:
# model-window2
# model-window4
# model-window8
# model-window16
# model-window32
# model-window64
# model-window128
# model-window256
# model-window512
# model-window1024
# ...
